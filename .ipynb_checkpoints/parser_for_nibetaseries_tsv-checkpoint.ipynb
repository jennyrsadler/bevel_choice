# %% [markdown]
# #PARSER FOR NIBETASERIES TSV FILES
#
# This script takes txt files parsed from bevel task log files & formats them for nibetaseries

# %%
import os
import glob
import pandas as pd
import numpy as np
import pdb

# %%
basepath='/Users/jennygilbert/Documents/bevel_choice/nibetaseries'
os.chdir(basepath)

# %%
basepath
# Out:
# '/Users/jennygilbert/Documents/bevel_choice/nibetaseries'

# %%
for file in glob.glob(os.path.join(basepath,'*.txt')):
    print(file)

    sub=file.split('/')[6].split('.')[0]
    print(sub_run)
    
    #read in data to pandas
    df = pd.read_csv(os.path.join(basepath,sub + '.txt'), sep='\t', header = None, names = ['ID','run','onset','duration','img_pair','choice','side','outcome','matched','RT'])
    #pdb.set_trace()
    df1 = df[df['img_pair'] == 'AB']
    
    #caculate learned probabilities
    cond = (df1.matched == 'matched')
    df1['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df1.matched == 'mismatched')
    df1['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df1.matched != 'Miss')
    df1['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)
    
    df1 = df1.replace(999,np.NaN)
    
    df1['a_learnedprob_correct'] = df1.matched_running / df1.reinforcer_running
    df1['b_learnedprob_correct'] = df1.mismatched_running / df1.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df1[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'

    df2["reinforcer_response"] = ""
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df1['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #DO FOR CD
    df3 = df[df['img_pair'] == 'CD']

    #caculate learned probabilities
    cond = (df3.matched == 'matched')
    df3['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df3.matched == 'mismatched')
    df3['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df3.matched != 'Miss')
    df3['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)

    df3 = df3.replace(999,np.NaN)

    df3['c_learnedprob_correct'] = df3.matched_running / df3.reinforcer_running
    df3['d_learnedprob_correct'] = df3.mismatched_running / df3.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df3[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'
    
    df2["reinforcer_response"] = ""
    
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df3['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #DO FOR EF
    df4 = df[df['img_pair'] == 'EF']

    #caculate learned probabilities
    cond = (df4.matched == 'matched')
    df4['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df4.matched == 'mismatched')
    df4['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df4.matched != 'Miss')
    df4['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)

    df4 = df4.replace(999,np.NaN)

    df4['e_learnedprob_correct'] = df4.matched_running / df4.reinforcer_running
    df4['f_learnedprob_correct'] = df4.mismatched_running / df4.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df4[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'
    
    df2["reinforcer_response"] = ""
    
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df4['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #Combine DFs and save
    combo_unsort = pd.concat([df1,df3,df4], sort=True)
    combo_long = combo_unsort.sort_index()

    cols = ['ID', 'run','onset','duration','img_pair','choice','side','outcome','matched','RT','reinforcer_response']
    combo_clean = combo_long[cols]
    combo_clean

    combo_clean.to_csv('sub-0'+sub+'_task-pst_events.tsv')
# Out:
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/01_run01.txt
# nibetaseries
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/01_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/01_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/01_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/02_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/02_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/02_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/02_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/03_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/03_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/03_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/03_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/04_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/04_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/04_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/04_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/05_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/05_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/05_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/05_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/06_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/06_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/06_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/06_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/07_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/07_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/07_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/07_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/08_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/08_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/08_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/08_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/09_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/09_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/09_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/09_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/10_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/10_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/10_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/10_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/11_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/11_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/11_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/11_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/12_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/12_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/12_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/12_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/13_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/13_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/13_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/13_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/14_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/14_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/14_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/14_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/15_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/15_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/15_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/15_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/16_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/16_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/16_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/16_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/17_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/17_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/17_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/17_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/18_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/18_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/18_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/18_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/19_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/19_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/19_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/19_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/20_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/20_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/20_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/20_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/21_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/21_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/21_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/21_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/22_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/22_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/22_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/22_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/23_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/23_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/24_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/24_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/24_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/24_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/25_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/25_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/25_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/25_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/26_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/26_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/26_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/26_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/27_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/27_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/27_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/27_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/28_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/28_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/28_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/28_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/29_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/29_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/29_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/29_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/30_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/30_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/30_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/30_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/31_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/31_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/31_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/31_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/32_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/32_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/32_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/32_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/33_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/33_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/33_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/33_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/34_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/34_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/34_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/34_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/35_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/35_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/35_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/35_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/36_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/36_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/36_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/36_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/37_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/37_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/37_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/37_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/38_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/38_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/38_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/38_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/39_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/39_run02.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/39_run03.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/39_run04.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries/40_run01.txt
# nibetaseries
# /Users/jennygilbert/Documents/bevel_choice/nibetaseries