# %% [markdown]
# # Bevel Choice Behavior Notebook

# %%
#imports
import os
import glob
import pandas as pd
import numpy as np
import matplotlib as plot

# %% [markdown]
# For one file... import data

# %%
path = '/Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles'
print(path)

df = pd.read_csv(os.path.join(path,'01.txt'), sep='\t', header = None, names = ['ID','run','img_pair','choice','side','outcome','matched','RT'])
df
# Out:
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles
#      ID    run img_pair choice  side outcome     matched        RT
# 0     1  run01       EF      F     1  reward  mismatched  1.569796
# 1     1  run01       CD      D     2  punish     matched  1.601124
# 2     1  run01       CD      D     2  punish     matched  1.600702
# 3     1  run01       CD   Miss  Miss    Miss        Miss      Miss
# 4     1  run01       AB      A     2  reward     matched  1.580793
# 5     1  run01       AB      B     2  reward  mismatched  1.564219
# 6     1  run01       AB      B     1  punish     matched  1.612839
# 7     1  run01       CD      D     2  punish     matched  1.594208
# 8     1  run01       CD      C     1  reward     matched  1.611155
# 9     1  run01       AB      A     1  punish  mismatched  1.594223
# 10    1  run01       EF      F     2  reward  mismatched  1.593177
# 11    1  run01       CD      D     2  punish     matched  1.590463
# 12    1  run01       AB      A     2  punish  mismatched  1.590193
# 13    1  run01       CD      C     1  reward     matched  1.605062
# 14    1  run01       CD      C     1  reward     matched  1.605347
# 15    1  run01       AB      A     1  punish  mismatched  1.587054
# 16    1  run01       CD      D     1  punish     matched  1.602987
# 17    1  run01       AB      A     1  reward     matched  1.602018
# 18    1  run01       AB      B     2  punish     matched  1.600867
# 19    1  run01       EF      E     2  reward     matched  1.582977
# 20    1  run01       AB   Miss  Miss    Miss        Miss      Miss
# 21    1  run01       AB      A     2  reward     matched  1.614960
# 22    1  run01       AB      B     1  reward  mismatched  1.580498
# 23    1  run01       CD      C     2  reward     matched  1.596363
# 24    1  run01       AB      A     1  reward     matched  1.596714
# 25    1  run01       CD   Miss  Miss    Miss        Miss      Miss
# 26    1  run02       EF      F     1  reward  mismatched  1.567948
# 27    1  run02       CD      D     1  reward  mismatched  1.583463
# 28    1  run02       AB      A     1  reward     matched  1.600016
# 29    1  run02       AB      B     2  punish     matched  1.599418
# ..   ..    ...      ...    ...   ...     ...         ...       ...
# 74    1  run03       AB      A     2  reward     matched  1.600248
# 75    1  run03       CD      C     2  reward     matched  1.615614
# 76    1  run03       AB      B     2  reward  mismatched  1.609683
# 77    1  run03       AB      B     1  punish     matched  1.609303
# 78    1  run04       AB      A     1  reward     matched  1.567914
# 79    1  run04       CD      C     2  punish  mismatched  1.566817
# 80    1  run04       AB      A     1  reward     matched  1.600015
# 81    1  run04       EF      E     2  punish  mismatched  1.597668
# 82    1  run04       EF      F     2  reward  mismatched  1.579999
# 83    1  run04       EF      F     2  punish     matched  1.579331
# 84    1  run04       AB      A     1  reward     matched  1.595599
# 85    1  run04       CD      C     1  reward     matched  1.610148
# 86    1  run04       AB      B     2  punish     matched  1.593779
# 87    1  run04       AB      B     2  punish     matched  1.592215
# 88    1  run04       CD   Miss  Miss    Miss        Miss      Miss
# 89    1  run04       CD   Miss  Miss    Miss        Miss      Miss
# 90    1  run04       EF      E     2  reward     matched  1.571638
# 91    1  run04       EF      F     1  reward  mismatched  1.603959
# 92    1  run04       EF      E     2  punish  mismatched  1.586667
# 93    1  run04       AB      A     2  reward     matched  1.602250
# 94    1  run04       CD      C     1  reward     matched  1.602497
# 95    1  run04       AB      B     2  punish     matched  1.583664
# 96    1  run04       CD      C     1  reward     matched  1.600436
# 97    1  run04       AB      B     2  reward  mismatched  1.582885
# 98    1  run04       CD      D     1  reward  mismatched  1.598864
# 99    1  run04       AB   Miss  Miss    Miss        Miss      Miss
# 100   1  run04       AB      B     2  punish     matched  1.596398
# 101   1  run04       CD      D     2  punish     matched  1.610596
# 102   1  run04       AB      A     2  reward     matched  1.576546
# 103   1  run04       AB      A     2  reward     matched  1.608679
#
# [104 rows x 8 columns]

# %%
#Goal = calculate probability of each shape as the sum of number of previous rewards/sum of number of previous reinforcers
#running matched/total reinforcers = A prob of correct
#running mismatched/total reinforcers = B prob of being correct

#Split df into AB
df1 = df[df['img_pair'] == 'AB']
df1
# Out:
#      ID    run img_pair choice  side outcome     matched        RT
# 4     1  run01       AB      A     2  reward     matched  1.580793
# 5     1  run01       AB      B     2  reward  mismatched  1.564219
# 6     1  run01       AB      B     1  punish     matched  1.612839
# 9     1  run01       AB      A     1  punish  mismatched  1.594223
# 12    1  run01       AB      A     2  punish  mismatched  1.590193
# 15    1  run01       AB      A     1  punish  mismatched  1.587054
# 17    1  run01       AB      A     1  reward     matched  1.602018
# 18    1  run01       AB      B     2  punish     matched  1.600867
# 20    1  run01       AB   Miss  Miss    Miss        Miss      Miss
# 21    1  run01       AB      A     2  reward     matched  1.614960
# 22    1  run01       AB      B     1  reward  mismatched  1.580498
# 24    1  run01       AB      A     1  reward     matched  1.596714
# 28    1  run02       AB      A     1  reward     matched  1.600016
# 29    1  run02       AB      B     2  punish     matched  1.599418
# 34    1  run02       AB      A     2  reward     matched  1.594216
# 36    1  run02       AB      B     2  punish     matched  1.607863
# 39    1  run02       AB      B     2  reward  mismatched  1.587784
# 40    1  run02       AB      A     2  reward     matched  1.604879
# 41    1  run02       AB      A     2  reward     matched  1.586674
# 52    1  run03       AB      A     2  reward     matched  1.583751
# 53    1  run03       AB      B     1  punish     matched  1.615984
# 56    1  run03       AB      B     2  punish     matched  1.620375
# 57    1  run03       AB      B     2  reward  mismatched  1.613717
# 60    1  run03       AB      B     2  punish     matched  1.610023
# 62    1  run03       AB      A     2  punish  mismatched  1.595104
# 63    1  run03       AB      B     2  punish     matched  1.607097
# 69    1  run03       AB      B     2  punish     matched  1.598565
# 71    1  run03       AB      B     2  punish     matched  1.596828
# 74    1  run03       AB      A     2  reward     matched  1.600248
# 76    1  run03       AB      B     2  reward  mismatched  1.609683
# 77    1  run03       AB      B     1  punish     matched  1.609303
# 78    1  run04       AB      A     1  reward     matched  1.567914
# 80    1  run04       AB      A     1  reward     matched  1.600015
# 84    1  run04       AB      A     1  reward     matched  1.595599
# 86    1  run04       AB      B     2  punish     matched  1.593779
# 87    1  run04       AB      B     2  punish     matched  1.592215
# 93    1  run04       AB      A     2  reward     matched  1.602250
# 95    1  run04       AB      B     2  punish     matched  1.583664
# 97    1  run04       AB      B     2  reward  mismatched  1.582885
# 99    1  run04       AB   Miss  Miss    Miss        Miss      Miss
# 100   1  run04       AB      B     2  punish     matched  1.596398
# 102   1  run04       AB      A     2  reward     matched  1.576546
# 103   1  run04       AB      A     2  reward     matched  1.608679

# %%
cond = (df1.matched == 'matched')
df1['matched_running'] = cond.cumsum().where(cond,999).astype(int)
df1

cond1 = (df1.matched == 'mismatched')
df1['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
df1

cond2 = (df1.matched != 'Miss')
df1['reinforcer_running'] = cond2.cumsum().where(cond2,999).astype(int)
df1

df1 = df1.replace(999, np.nan)
df1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#      ID    run img_pair choice  side outcome     matched        RT  \
# 4     1  run01       AB      A     2  reward     matched  1.580793
# 5     1  run01       AB      B     2  reward  mismatched  1.564219
# 6     1  run01       AB      B     1  punish     matched  1.612839
# 9     1  run01       AB      A     1  punish  mismatched  1.594223
# 12    1  run01       AB      A     2  punish  mismatched  1.590193
# 15    1  run01       AB      A     1  punish  mismatched  1.587054
# 17    1  run01       AB      A     1  reward     matched  1.602018
# 18    1  run01       AB      B     2  punish     matched  1.600867
# 20    1  run01       AB   Miss  Miss    Miss        Miss      Miss
# 21    1  run01       AB      A     2  reward     matched  1.614960
# 22    1  run01       AB      B     1  reward  mismatched  1.580498
# 24    1  run01       AB      A     1  reward     matched  1.596714
# 28    1  run02       AB      A     1  reward     matched  1.600016
# 29    1  run02       AB      B     2  punish     matched  1.599418
# 34    1  run02       AB      A     2  reward     matched  1.594216
# 36    1  run02       AB      B     2  punish     matched  1.607863
# 39    1  run02       AB      B     2  reward  mismatched  1.587784
# 40    1  run02       AB      A     2  reward     matched  1.604879
# 41    1  run02       AB      A     2  reward     matched  1.586674
# 52    1  run03       AB      A     2  reward     matched  1.583751
# 53    1  run03       AB      B     1  punish     matched  1.615984
# 56    1  run03       AB      B     2  punish     matched  1.620375
# 57    1  run03       AB      B     2  reward  mismatched  1.613717
# 60    1  run03       AB      B     2  punish     matched  1.610023
# 62    1  run03       AB      A     2  punish  mismatched  1.595104
# 63    1  run03       AB      B     2  punish     matched  1.607097
# 69    1  run03       AB      B     2  punish     matched  1.598565
# 71    1  run03       AB      B     2  punish     matched  1.596828
# 74    1  run03       AB      A     2  reward     matched  1.600248
# 76    1  run03       AB      B     2  reward  mismatched  1.609683
# 77    1  run03       AB      B     1  punish     matched  1.609303
# 78    1  run04       AB      A     1  reward     matched  1.567914
# 80    1  run04       AB      A     1  reward     matched  1.600015
# 84    1  run04       AB      A     1  reward     matched  1.595599
# 86    1  run04       AB      B     2  punish     matched  1.593779
# 87    1  run04       AB      B     2  punish     matched  1.592215
# 93    1  run04       AB      A     2  reward     matched  1.602250
# 95    1  run04       AB      B     2  punish     matched  1.583664
# 97    1  run04       AB      B     2  reward  mismatched  1.582885
# 99    1  run04       AB   Miss  Miss    Miss        Miss      Miss
# 100   1  run04       AB      B     2  punish     matched  1.596398
# 102   1  run04       AB      A     2  reward     matched  1.576546
# 103   1  run04       AB      A     2  reward     matched  1.608679
#
#      matched_running  mismatched_running  reinforcer_running
# 4                1.0                 NaN                 1.0
# 5                NaN                 1.0                 2.0
# 6                2.0                 NaN                 3.0
# 9                NaN                 2.0                 4.0
# 12               NaN                 3.0                 5.0
# 15               NaN                 4.0                 6.0
# 17               3.0                 NaN                 7.0
# 18               4.0                 NaN                 8.0
# 20               NaN                 NaN                 NaN
# 21               5.0                 NaN                 9.0
# 22               NaN                 5.0                10.0
# 24               6.0                 NaN                11.0
# 28               7.0                 NaN                12.0
# 29               8.0                 NaN                13.0
# 34               9.0                 NaN                14.0
# 36              10.0                 NaN                15.0
# 39               NaN                 6.0                16.0
# 40              11.0                 NaN                17.0
# 41              12.0                 NaN                18.0
# 52              13.0                 NaN                19.0
# 53              14.0                 NaN                20.0
# 56              15.0                 NaN                21.0
# 57               NaN                 7.0                22.0
# 60              16.0                 NaN                23.0
# 62               NaN                 8.0                24.0
# 63              17.0                 NaN                25.0
# 69              18.0                 NaN                26.0
# 71              19.0                 NaN                27.0
# 74              20.0                 NaN                28.0
# 76               NaN                 9.0                29.0
# 77              21.0                 NaN                30.0
# 78              22.0                 NaN                31.0
# 80              23.0                 NaN                32.0
# 84              24.0                 NaN                33.0
# 86              25.0                 NaN                34.0
# 87              26.0                 NaN                35.0
# 93              27.0                 NaN                36.0
# 95              28.0                 NaN                37.0
# 97               NaN                10.0                38.0
# 99               NaN                 NaN                 NaN
# 100             29.0                 NaN                39.0
# 102             30.0                 NaN                40.0
# 103             31.0                 NaN                41.0

# %%
df1['a_corr_prob'] = df1.matched_running / df1.reinforcer_running
df1['b_corr_prob'] = df1.mismatched_running / df1.reinforcer_running
df1
# Out:
#      ID    run img_pair choice  side outcome     matched        RT  \
# 4     1  run01       AB      A     2  reward     matched  1.580793
# 5     1  run01       AB      B     2  reward  mismatched  1.564219
# 6     1  run01       AB      B     1  punish     matched  1.612839
# 9     1  run01       AB      A     1  punish  mismatched  1.594223
# 12    1  run01       AB      A     2  punish  mismatched  1.590193
# 15    1  run01       AB      A     1  punish  mismatched  1.587054
# 17    1  run01       AB      A     1  reward     matched  1.602018
# 18    1  run01       AB      B     2  punish     matched  1.600867
# 20    1  run01       AB   Miss  Miss    Miss        Miss      Miss
# 21    1  run01       AB      A     2  reward     matched  1.614960
# 22    1  run01       AB      B     1  reward  mismatched  1.580498
# 24    1  run01       AB      A     1  reward     matched  1.596714
# 28    1  run02       AB      A     1  reward     matched  1.600016
# 29    1  run02       AB      B     2  punish     matched  1.599418
# 34    1  run02       AB      A     2  reward     matched  1.594216
# 36    1  run02       AB      B     2  punish     matched  1.607863
# 39    1  run02       AB      B     2  reward  mismatched  1.587784
# 40    1  run02       AB      A     2  reward     matched  1.604879
# 41    1  run02       AB      A     2  reward     matched  1.586674
# 52    1  run03       AB      A     2  reward     matched  1.583751
# 53    1  run03       AB      B     1  punish     matched  1.615984
# 56    1  run03       AB      B     2  punish     matched  1.620375
# 57    1  run03       AB      B     2  reward  mismatched  1.613717
# 60    1  run03       AB      B     2  punish     matched  1.610023
# 62    1  run03       AB      A     2  punish  mismatched  1.595104
# 63    1  run03       AB      B     2  punish     matched  1.607097
# 69    1  run03       AB      B     2  punish     matched  1.598565
# 71    1  run03       AB      B     2  punish     matched  1.596828
# 74    1  run03       AB      A     2  reward     matched  1.600248
# 76    1  run03       AB      B     2  reward  mismatched  1.609683
# 77    1  run03       AB      B     1  punish     matched  1.609303
# 78    1  run04       AB      A     1  reward     matched  1.567914
# 80    1  run04       AB      A     1  reward     matched  1.600015
# 84    1  run04       AB      A     1  reward     matched  1.595599
# 86    1  run04       AB      B     2  punish     matched  1.593779
# 87    1  run04       AB      B     2  punish     matched  1.592215
# 93    1  run04       AB      A     2  reward     matched  1.602250
# 95    1  run04       AB      B     2  punish     matched  1.583664
# 97    1  run04       AB      B     2  reward  mismatched  1.582885
# 99    1  run04       AB   Miss  Miss    Miss        Miss      Miss
# 100   1  run04       AB      B     2  punish     matched  1.596398
# 102   1  run04       AB      A     2  reward     matched  1.576546
# 103   1  run04       AB      A     2  reward     matched  1.608679
#
#      matched_running  mismatched_running  reinforcer_running  a_corr_prob  \
# 4                1.0                 NaN                 1.0     1.000000
# 5                NaN                 1.0                 2.0          NaN
# 6                2.0                 NaN                 3.0     0.666667
# 9                NaN                 2.0                 4.0          NaN
# 12               NaN                 3.0                 5.0          NaN
# 15               NaN                 4.0                 6.0          NaN
# 17               3.0                 NaN                 7.0     0.428571
# 18               4.0                 NaN                 8.0     0.500000
# 20               NaN                 NaN                 NaN          NaN
# 21               5.0                 NaN                 9.0     0.555556
# 22               NaN                 5.0                10.0          NaN
# 24               6.0                 NaN                11.0     0.545455
# 28               7.0                 NaN                12.0     0.583333
# 29               8.0                 NaN                13.0     0.615385
# 34               9.0                 NaN                14.0     0.642857
# 36              10.0                 NaN                15.0     0.666667
# 39               NaN                 6.0                16.0          NaN
# 40              11.0                 NaN                17.0     0.647059
# 41              12.0                 NaN                18.0     0.666667
# 52              13.0                 NaN                19.0     0.684211
# 53              14.0                 NaN                20.0     0.700000
# 56              15.0                 NaN                21.0     0.714286
# 57               NaN                 7.0                22.0          NaN
# 60              16.0                 NaN                23.0     0.695652
# 62               NaN                 8.0                24.0          NaN
# 63              17.0                 NaN                25.0     0.680000
# 69              18.0                 NaN                26.0     0.692308
# 71              19.0                 NaN                27.0     0.703704
# 74              20.0                 NaN                28.0     0.714286
# 76               NaN                 9.0                29.0          NaN
# 77              21.0                 NaN                30.0     0.700000
# 78              22.0                 NaN                31.0     0.709677
# 80              23.0                 NaN                32.0     0.718750
# 84              24.0                 NaN                33.0     0.727273
# 86              25.0                 NaN                34.0     0.735294
# 87              26.0                 NaN                35.0     0.742857
# 93              27.0                 NaN                36.0     0.750000
# 95              28.0                 NaN                37.0     0.756757
# 97               NaN                10.0                38.0          NaN
# 99               NaN                 NaN                 NaN          NaN
# 100             29.0                 NaN                39.0     0.743590
# 102             30.0                 NaN                40.0     0.750000
# 103             31.0                 NaN                41.0     0.756098
#
#      b_corr_prob
# 4            NaN
# 5       0.500000
# 6            NaN
# 9       0.500000
# 12      0.600000
# 15      0.666667
# 17           NaN
# 18           NaN
# 20           NaN
# 21           NaN
# 22      0.500000
# 24           NaN
# 28           NaN
# 29           NaN
# 34           NaN
# 36           NaN
# 39      0.375000
# 40           NaN
# 41           NaN
# 52           NaN
# 53           NaN
# 56           NaN
# 57      0.318182
# 60           NaN
# 62      0.333333
# 63           NaN
# 69           NaN
# 71           NaN
# 74           NaN
# 76      0.310345
# 77           NaN
# 78           NaN
# 80           NaN
# 84           NaN
# 86           NaN
# 87           NaN
# 93           NaN
# 95           NaN
# 97      0.263158
# 99           NaN
# 100          NaN
# 102          NaN
# 103          NaN

# %%
df1.to_csv('01_test.csv')
