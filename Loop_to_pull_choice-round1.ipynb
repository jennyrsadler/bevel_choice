# %%
import os
import glob
import pandas as pd
import numpy as np
import pdb

# %%
basepath='/Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles'
os.chdir(basepath)

# %%
for file in glob.glob(os.path.join(basepath,'*.txt')):
    print(file)

    sub=file.split('/')[6].split('.')[0]
    print(sub)
    
    #read in data to pandas
    df = pd.read_csv(os.path.join(basepath,sub + '.txt'), sep='\t', header = None, names = ['ID','run','img_pair','choice','side','outcome','matched','RT'])
    #pdb.set_trace()
    df1 = df[df['img_pair'] == 'AB']
    
    #caculate learned probabilities
    cond = (df1.matched == 'matched')
    df1['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df1.matched == 'mismatched')
    df1['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df1.matched != 'Miss')
    df1['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)
    
    df1 = df1.replace(999,np.NaN)
    
    df1['a_learnedprob_correct'] = df1.matched_running / df1.reinforcer_running
    df1['b_learnedprob_correct'] = df1.mismatched_running / df1.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df1[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'

    df2["reinforcer_response"] = ""
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df1['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #DO FOR CD
    df3 = df[df['img_pair'] == 'CD']

    #caculate learned probabilities
    cond = (df3.matched == 'matched')
    df3['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df3.matched == 'mismatched')
    df3['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df3.matched != 'Miss')
    df3['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)

    df3 = df3.replace(999,np.NaN)

    df3['c_learnedprob_correct'] = df3.matched_running / df3.reinforcer_running
    df3['d_learnedprob_correct'] = df3.mismatched_running / df3.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df3[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'
    
    df2["reinforcer_response"] = ""
    
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df3['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #DO FOR EF
    df4 = df[df['img_pair'] == 'EF']

    #caculate learned probabilities
    cond = (df4.matched == 'matched')
    df4['matched_running'] = cond.cumsum().where(cond, 999).astype(int)
    cond1 = (df4.matched == 'mismatched')
    df4['mismatched_running'] = cond1.cumsum().where(cond1,999).astype(int)
    cond2 = (df4.matched != 'Miss')
    df4['reinforcer_running'] = cond2.cumsum().where(cond2, 999).astype(int)

    df4 = df4.replace(999,np.NaN)

    df4['e_learnedprob_correct'] = df4.matched_running / df4.reinforcer_running
    df4['f_learnedprob_correct'] = df4.mismatched_running / df4.reinforcer_running
    
    #create new variable for reinforcer response 
    df2 = df4[['choice','outcome']].copy()
    df2["behavior"] = ""
    count = df2.choice.count()
    count = count - 1 
    list = np.arange(0, count)

    for i in list: 
        if df2.iloc[i, 0] == df2.iloc[i+1, 0]:
            df2.iloc[i+1, 2] = 'same letter'
    
        elif df2.iloc[i,0] == 'Miss':
            df2.iloc[i+1, 2] = 'post-miss'
            df2.iloc[i,2] = 'miss'
        else: 
            df2.iloc[i+1, 2] ='new letter'
    
    df2["reinforcer_response"] = ""
    
    for i in list: 
        if df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'exploit_reward'
    
        elif df2.iloc[i+1, 2] == 'same letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'explore_punish'

        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'reward':
            df2.iloc[i+1, 3] = 'explore_reward'
    
        elif df2.iloc[i+1, 2] == 'new letter' and df2.iloc[i, 1] == 'punish':
            df2.iloc[i+1, 3] = 'exploit_punish'   
    
        else: df2.iloc[i+1, 3] = 'miss_response'
    
    df4['reinforcer_response'] = pd.Series(df2['reinforcer_response'])
    
    #Combine DFs and save
    combo_unsort = pd.concat([df1,df3,df4], sort=True)
    combo_long = combo_unsort.sort_index()

    cols = ['ID', 'run','img_pair','choice','side','outcome','matched','RT','a_learnedprob_correct','b_learnedprob_correct','c_learnedprob_correct','d_learnedprob_correct','e_learnedprob_correct','f_learnedprob_correct','reinforcer_response']
    combo_clean = combo_long[cols]
    combo_clean

    combo_clean.to_csv(sub+'.csv')
# Out:
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/01.txt
# 01
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/02.txt
# 02
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/03.txt
# 03
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/04.txt
# 04
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/05.txt
# 05
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/06.txt
# 06
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/07.txt
# 07
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/08.txt
# 08
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/09.txt
# 09
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/10.txt
# 10
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/11.txt
# 11
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/12.txt
# 12
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/13.txt
# 13
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/14.txt
# 14
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/15.txt
# 15
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/16.txt
# 16
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/17.txt
# 17
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/18.txt
# 18
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/19.txt
# 19
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/20.txt
# 20
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/21.txt
# 21
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/22.txt
# 22
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/23.txt
# 23
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/24.txt
# 24
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/25.txt
# 25
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/26.txt
# 26
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/27.txt
# 27
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/28.txt
# 28
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/29.txt
# 29
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/30.txt
# 30
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/31.txt
# 31
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/32.txt
# 32
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/33.txt
# 33
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/34.txt
# 34
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/35.txt
# 35
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/36.txt
# 36
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/37.txt
# 37
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/38.txt
# 38
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/39.txt
# 39
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/40.txt
# 40
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/41.txt
# 41
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/42.txt
# 42
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/43.txt
# 43
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/44.txt
# 44
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/45.txt
# 45
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/46.txt
# 46
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/47.txt
# 47
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/48.txt
# 48
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/49.txt
# 49
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/50.txt
# 50
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/51.txt
# 51
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/52.txt
# 52
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/53.txt
# 53
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/54.txt
# 54
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/55.txt
# 55
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/56.txt
# 56
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/57.txt
# 57
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/58.txt
# 58
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/59.txt
# 59
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/60.txt
# 60
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/61.txt
# 61
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/62.txt
# 62
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/63.txt
# 63
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/64.txt
# 64
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/65.txt
# 65
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/66.txt
# 66
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/67.txt
# 67
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/68.txt
# 68
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/69.txt
# 69
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/70.txt
# 70
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/71.txt
# 71
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/72.txt
# 72
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/73.txt
# 73
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/74.txt
# 74
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/75.txt
# 75
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/76.txt
# 76
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/77.txt
# 77
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/78.txt
# 78
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/79.txt
# 79
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/80.txt
# 80
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/81.txt
# 81
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/82.txt
# 82
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/83.txt
# 83
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/84.txt
# 84
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/85.txt
# 85
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/86.txt
# 86
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/87.txt
# 87
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/88.txt
# 88
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/89.txt
# 89
# /Users/jennygilbert/Documents/bevel_choice/by_participant_txtfiles/90.txt
# 90
